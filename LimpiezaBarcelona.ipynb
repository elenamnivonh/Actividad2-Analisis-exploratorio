# %%
#Carga de librerias 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics as mode

# %%
#Carga de archivo CSV
data= pd.read_csv("Barcelona.csv", encoding= 'ISO-8859-1')
data
# Out:
#                        id                                               name  \
# 0      673276379194656210                         HabitaciÃ³n muy acogedora.
# 1                44192271      Cozy terrace apartment\nApartamento con patio
# 2                  196021  Large patio, 4 baths (3 en-suite), 19th c, cen...
# 3                  196196  â¨Large Apt near Sagrada Familia / Shared ter...
# 4                   18674    Huge flat for 8 people close to Sagrada Familia
# ...                   ...                                                ...
# 16915            26383234  LOVELY PRIVATE ROOM FOR 6 GUESTS ENSUITE BATHROOM
# 16916            26383143  LOVELY PRIVATE ROOM FOR 6 GUESTS ENSUITE BATHROOM
# 16917            26384664  HABITACION PRIVADA DE 6 CAMAS CON TERRAZA PRIVADA
# 16918            18220085  Chillout house,  with garden and pool  for family
# 16919             5122846  3 Peaceful, double bedrooms in musical family ...
#
#          host_id                     host_name   neighbourhood_group  \
# 0       51421682              Maria Das Merces       Sants-MontjuÃ¯c
# 1      200754964                         Nuria             Les Corts
# 2         953719                         Julia              Eixample
# 3         567180                        Sandra              Eixample
# 4          71615              Mireia And Maria              Eixample
# ...          ...                           ...                   ...
# 16915  198281707  Casa Barcelo Camp Nou Hostel             Les Corts
# 16916  198281707  Casa Barcelo Camp Nou Hostel             Les Corts
# 16917  198281707  Casa Barcelo Camp Nou Hostel             Les Corts
# 16918   10030977              Sven Et Michaela             Les Corts
# 16919    1145453                        Zabeth  SarriÃ -Sant Gervasi
#
#                                neighbourhood   latitude  longitude  \
# 0                                 la Bordeta  41.363004   2.125326
# 1                 la Maternitat i Sant Ramon  41.372630   2.113180
# 2            l'Antiga Esquerra de l'Eixample  41.388420   2.161080
# 3                        la Sagrada FamÃ­lia  41.406600   2.174590
# 4                        la Sagrada FamÃ­lia  41.405560   2.172620
# ...                                      ...        ...        ...
# 16915             la Maternitat i Sant Ramon  41.373770   2.117570
# 16916             la Maternitat i Sant Ramon  41.373770   2.117570
# 16917             la Maternitat i Sant Ramon  41.374110   2.118520
# 16918                              Pedralbes  41.388440   2.087890
# 16919  Vallvidrera, el Tibidabo i les Planes  41.385100   2.076420
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0         Private room     59               1                  9  2022-09-08
# 1      Entire home/apt    110               3                 54  2022-08-26
# 2      Entire home/apt    386               4                316  2022-08-12
# 3      Entire home/apt    245               2                103  2022-08-10
# 4      Entire home/apt    180               1                 30  2022-08-29
# ...                ...    ...             ...                ...         ...
# 16915     Private room   5000               1                 30  2019-12-27
# 16916     Private room   5000               1                  2  2019-02-17
# 16917     Private room   5000               1                 13  2020-02-19
# 16918  Entire home/apt    250               6                 12  2022-07-29
# 16919     Private room     33               1                  5  2022-06-13
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   9.00                               1               351
# 1                   2.45                               1               151
# 2                   2.37                               1               238
# 3                   0.77                              19                22
# 4                   0.27                              38                60
# ...                  ...                             ...               ...
# 16915               0.59                              12                 0
# 16916               0.05                              12                 0
# 16917               0.33                              12                 0
# 16918               0.19                               1                 0
# 16919               0.06                               3                 0
#
#        number_of_reviews_ltm      license
# 0                          9       Exempt
# 1                         40  HUTB-013294
# 2                         45  HUTB-506707
# 3                         11  HUTB-000325
# 4                          9  HUTB-002062
# ...                      ...          ...
# 16915                      0  HUTB-172880
# 16916                      0  HUTB-172880
# 16917                      0  HUTB-172880
# 16918                      2  HUTB-017296
# 16919                      2          NaN
#
# [16920 rows x 18 columns]

# %% [markdown]
# ##########TRATADO DE NULOS##########

# %%
#Identificación de valores nulos
null=data.isnull(). sum()
null
# Out:
# id                                   0
# name                                10
# host_id                              0
# host_name                            2
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       3614
# reviews_per_month                 3614
# calculated_host_listings_count       0
# availability_365                     0
# number_of_reviews_ltm                0
# license                           5328
# dtype: int64

# %%
#Eliminación de columnas neighbourhood_group
data0=data.drop(['neighbourhood_group'], axis=1)
data1=data0.drop(['last_review'], axis=1)
data2=data1.drop(['license'], axis=1)
data2
# Out:
#                        id                                               name  \
# 0      673276379194656210                         HabitaciÃ³n muy acogedora.
# 1                44192271      Cozy terrace apartment\nApartamento con patio
# 2                  196021  Large patio, 4 baths (3 en-suite), 19th c, cen...
# 3                  196196  â¨Large Apt near Sagrada Familia / Shared ter...
# 4                   18674    Huge flat for 8 people close to Sagrada Familia
# ...                   ...                                                ...
# 16915            26383234  LOVELY PRIVATE ROOM FOR 6 GUESTS ENSUITE BATHROOM
# 16916            26383143  LOVELY PRIVATE ROOM FOR 6 GUESTS ENSUITE BATHROOM
# 16917            26384664  HABITACION PRIVADA DE 6 CAMAS CON TERRAZA PRIVADA
# 16918            18220085  Chillout house,  with garden and pool  for family
# 16919             5122846  3 Peaceful, double bedrooms in musical family ...
#
#          host_id                     host_name  \
# 0       51421682              Maria Das Merces
# 1      200754964                         Nuria
# 2         953719                         Julia
# 3         567180                        Sandra
# 4          71615              Mireia And Maria
# ...          ...                           ...
# 16915  198281707  Casa Barcelo Camp Nou Hostel
# 16916  198281707  Casa Barcelo Camp Nou Hostel
# 16917  198281707  Casa Barcelo Camp Nou Hostel
# 16918   10030977              Sven Et Michaela
# 16919    1145453                        Zabeth
#
#                                neighbourhood   latitude  longitude  \
# 0                                 la Bordeta  41.363004   2.125326
# 1                 la Maternitat i Sant Ramon  41.372630   2.113180
# 2            l'Antiga Esquerra de l'Eixample  41.388420   2.161080
# 3                        la Sagrada FamÃ­lia  41.406600   2.174590
# 4                        la Sagrada FamÃ­lia  41.405560   2.172620
# ...                                      ...        ...        ...
# 16915             la Maternitat i Sant Ramon  41.373770   2.117570
# 16916             la Maternitat i Sant Ramon  41.373770   2.117570
# 16917             la Maternitat i Sant Ramon  41.374110   2.118520
# 16918                              Pedralbes  41.388440   2.087890
# 16919  Vallvidrera, el Tibidabo i les Planes  41.385100   2.076420
#
#              room_type  price  minimum_nights  number_of_reviews  \
# 0         Private room     59               1                  9
# 1      Entire home/apt    110               3                 54
# 2      Entire home/apt    386               4                316
# 3      Entire home/apt    245               2                103
# 4      Entire home/apt    180               1                 30
# ...                ...    ...             ...                ...
# 16915     Private room   5000               1                 30
# 16916     Private room   5000               1                  2
# 16917     Private room   5000               1                 13
# 16918  Entire home/apt    250               6                 12
# 16919     Private room     33               1                  5
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   9.00                               1               351
# 1                   2.45                               1               151
# 2                   2.37                               1               238
# 3                   0.77                              19                22
# 4                   0.27                              38                60
# ...                  ...                             ...               ...
# 16915               0.59                              12                 0
# 16916               0.05                              12                 0
# 16917               0.33                              12                 0
# 16918               0.19                               1                 0
# 16919               0.06                               3                 0
#
#        number_of_reviews_ltm
# 0                          9
# 1                         40
# 2                         45
# 3                         11
# 4                          9
# ...                      ...
# 16915                      0
# 16916                      0
# 16917                      0
# 16918                      2
# 16919                      2
#
# [16920 rows x 15 columns]

# %%
#Sustitución de "name"
data2["name"]=data2["name"].fillna('Usuario Desconocido')

#"reviews_per_month": Rellenar con el valor de “Media” de la columna
data2["reviews_per_month"]=data2["reviews_per_month"].fillna(round(data2["reviews_per_month"].mean(),1))

#Sustitución datos nulos en "host_name"
data2["host_name"]=data2["host_name"].bfill

# %%
#Identificación de valores nulos
null=data2.isnull(). sum()
null
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# dtype: int64

# %% [markdown]
# #####TRATADO DE OUTLIERS#####

# %%
#Creación de una copia para la base de datos
copia = data2.copy()

# %%
T2=copia
limitesuperiorT2=T2.mean()+2*T2.std()
limiteinferiorT2=T2.mean()-2*T2.std()
print("Limite superior permitido", limitesuperiorT2)
print("Limite inferior permitido",limiteinferiorT2)
# Out:
# /var/folders/km/_mk7wy_d31z7cvt46ch2p8mh0000gn/T/ipykernel_55194/1340371751.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   limitesuperiorT2=T2.mean()+2*T2.std()
# Limite superior permitido id                                6.061331e+17
# host_id                           4.278088e+08
# latitude                          4.142422e+01
# longitude                         2.210813e+00
# price                             2.028006e+03
# minimum_nights                    7.373701e+01
# number_of_reviews                 1.957064e+02
# reviews_per_month                 4.587359e+00
# calculated_host_listings_count    8.979183e+01
# availability_365                  4.354987e+02
# number_of_reviews_ltm             5.504350e+01
# dtype: float64
# Limite inferior permitido id                               -3.768163e+17
# host_id                          -1.517226e+08
# latitude                          4.135879e+01
# longitude                         2.119425e+00
# price                            -1.682177e+03
# minimum_nights                   -4.719611e+01
# number_of_reviews                -1.136481e+02
# reviews_per_month                -1.762762e+00
# calculated_host_listings_count   -5.077859e+01
# availability_365                 -9.386865e+01
# number_of_reviews_ltm            -3.281903e+01
# dtype: float64
# /var/folders/km/_mk7wy_d31z7cvt46ch2p8mh0000gn/T/ipykernel_55194/1340371751.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   limiteinferiorT2=T2.mean()-2*T2.std()

# %%
#Encontramos Ouliers del Dataframe
outliers= copia[(T2>limitesuperiorT2)|(T2<limiteinferiorT2)]
outliers
# Out:
# /var/folders/km/_mk7wy_d31z7cvt46ch2p8mh0000gn/T/ipykernel_55194/3983630926.py:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers= copia[(T2>limitesuperiorT2)|(T2<limiteinferiorT2)]
#                  id name  host_id host_name neighbourhood  latitude  \
# 0      6.732764e+17  NaN      NaN       NaN           NaN       NaN
# 1               NaN  NaN      NaN       NaN           NaN       NaN
# 2               NaN  NaN      NaN       NaN           NaN       NaN
# 3               NaN  NaN      NaN       NaN           NaN       NaN
# 4               NaN  NaN      NaN       NaN           NaN       NaN
# ...             ...  ...      ...       ...           ...       ...
# 16915           NaN  NaN      NaN       NaN           NaN       NaN
# 16916           NaN  NaN      NaN       NaN           NaN       NaN
# 16917           NaN  NaN      NaN       NaN           NaN       NaN
# 16918           NaN  NaN      NaN       NaN           NaN       NaN
# 16919           NaN  NaN      NaN       NaN           NaN       NaN
#
#        longitude room_type   price  minimum_nights  number_of_reviews  \
# 0            NaN       NaN     NaN             NaN                NaN
# 1        2.11318       NaN     NaN             NaN                NaN
# 2            NaN       NaN     NaN             NaN              316.0
# 3            NaN       NaN     NaN             NaN                NaN
# 4            NaN       NaN     NaN             NaN                NaN
# ...          ...       ...     ...             ...                ...
# 16915    2.11757       NaN  5000.0             NaN                NaN
# 16916    2.11757       NaN  5000.0             NaN                NaN
# 16917    2.11852       NaN  5000.0             NaN                NaN
# 16918    2.08789       NaN     NaN             NaN                NaN
# 16919    2.07642       NaN     NaN             NaN                NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                    9.0                             NaN               NaN
# 1                    NaN                             NaN               NaN
# 2                    NaN                             NaN               NaN
# 3                    NaN                             NaN               NaN
# 4                    NaN                             NaN               NaN
# ...                  ...                             ...               ...
# 16915                NaN                             NaN               NaN
# 16916                NaN                             NaN               NaN
# 16917                NaN                             NaN               NaN
# 16918                NaN                             NaN               NaN
# 16919                NaN                             NaN               NaN
#
#        number_of_reviews_ltm
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 16915                    NaN
# 16916                    NaN
# 16917                    NaN
# 16918                    NaN
# 16919                    NaN
#
# [16920 rows x 15 columns]

# %%
#Conversion de Outliers a datos nulos
Outliers2=copia[(T2<=limitesuperiorT2) & (T2>=limiteinferiorT2)]
Outliers2
# Out:
# /var/folders/km/_mk7wy_d31z7cvt46ch2p8mh0000gn/T/ipykernel_55194/3054233424.py:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version. Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   Outliers2=copia[(T2<=limitesuperiorT2) & (T2>=limiteinferiorT2)]
#                id name      host_id host_name neighbourhood   latitude  \
# 0             NaN  NaN   51421682.0       NaN           NaN  41.363004
# 1      44192271.0  NaN  200754964.0       NaN           NaN  41.372630
# 2        196021.0  NaN     953719.0       NaN           NaN  41.388420
# 3        196196.0  NaN     567180.0       NaN           NaN  41.406600
# 4         18674.0  NaN      71615.0       NaN           NaN  41.405560
# ...           ...  ...          ...       ...           ...        ...
# 16915  26383234.0  NaN  198281707.0       NaN           NaN  41.373770
# 16916  26383143.0  NaN  198281707.0       NaN           NaN  41.373770
# 16917  26384664.0  NaN  198281707.0       NaN           NaN  41.374110
# 16918  18220085.0  NaN   10030977.0       NaN           NaN  41.388440
# 16919   5122846.0  NaN    1145453.0       NaN           NaN  41.385100
#
#        longitude room_type  price  minimum_nights  number_of_reviews  \
# 0       2.125326       NaN   59.0             1.0                9.0
# 1            NaN       NaN  110.0             3.0               54.0
# 2       2.161080       NaN  386.0             4.0                NaN
# 3       2.174590       NaN  245.0             2.0              103.0
# 4       2.172620       NaN  180.0             1.0               30.0
# ...          ...       ...    ...             ...                ...
# 16915        NaN       NaN    NaN             1.0               30.0
# 16916        NaN       NaN    NaN             1.0                2.0
# 16917        NaN       NaN    NaN             1.0               13.0
# 16918        NaN       NaN  250.0             6.0               12.0
# 16919        NaN       NaN   33.0             1.0                5.0
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                    NaN                             1.0               351
# 1                   2.45                             1.0               151
# 2                   2.37                             1.0               238
# 3                   0.77                            19.0                22
# 4                   0.27                            38.0                60
# ...                  ...                             ...               ...
# 16915               0.59                            12.0                 0
# 16916               0.05                            12.0                 0
# 16917               0.33                            12.0                 0
# 16918               0.19                             1.0                 0
# 16919               0.06                             3.0                 0
#
#        number_of_reviews_ltm
# 0                        9.0
# 1                       40.0
# 2                       45.0
# 3                       11.0
# 4                        9.0
# ...                      ...
# 16915                    0.0
# 16916                    0.0
# 16917                    0.0
# 16918                    2.0
# 16919                    2.0
#
# [16920 rows x 15 columns]

# %%
#sustituirl datos nulos por el promedio de la columna
copia["price"]=copia["price"].fillna(round(copia["price"].mean(),1))
copia["minimum_nights"]=copia["minimum_nights"].fillna(round(copia["minimum_nights"].mean(),1))
copia["number_of_reviews"]=copia["number_of_reviews"].fillna(round(copia["number_of_reviews"].mean(),1))
copia["reviews_per_month"]=copia["reviews_per_month"].fillna(round(copia["reviews_per_month"].mean(),1))
copia["calculated_host_listings_count"]=copia["calculated_host_listings_count"].fillna(round(copia["calculated_host_listings_count"].mean(),1))
copia["availability_365"]=copia["availability_365"].fillna(round(copia["availability_365"].mean(),1))
copia["number_of_reviews_ltm"]=copia["number_of_reviews_ltm"].fillna(round(copia["number_of_reviews_ltm"].mean(),1))

# %%
copia.to_csv('Barcelona_limpio.csv')

# %% [markdown]
# ##### Análisis de Correlación #####

# %%
#DEFINIMOS LA BASE DE DATOS 
dataframe= pd.read_csv("Barcelona_limpio.csv")

# %%
Dep=dataframe['price']

# %%
#Se define model como la  de regresión lineal
from sklearn.linear_model import LinearRegression
import seaborn as sns
model1=LinearRegression()

# %%
#A) PRICE - Minimum nights

Indepa=dataframe[['minimum_nights']]
model1.fit(X=Indepa, y=Dep)

#Coeficiente de determinación A)
coef_Detera = model1.score(X=Indepa, y=Dep)
coef_Detera
# Out:
# 0.019168473426433796

# %%
#Correlación 1
coef_Correlacion1=np.sqrt(coef_Detera)
coef_Correlacion1
# Out:
# 0.1384502561443416

# %%
#B) PRICE -  Number of reviews

Indepa=dataframe[['number_of_reviews']]
model1.fit(X=Indepa, y=Dep)

#Coeficiente de determinación B)
coef_Detera2 = model1.score(X=Indepa, y=Dep)
coef_Detera2
# Out:
# 2.233961724706912e-05

# %%
#Correlación 2
coef_Correlacion2=np.sqrt(coef_Detera2)
coef_Correlacion2
# Out:
# 0.004726480429142717

# %%
#C) PRICE - reviews_per_month

Indepa=dataframe[['reviews_per_month']]
model1.fit(X=Indepa, y=Dep)

#Coeficiente de determinación C)
coef_Detera3 = model1.score(X=Indepa, y=Dep)
coef_Detera3
# Out:
# 6.878732425674716e-05

# %%
#Correlación 3
coef_Correlacion3=np.sqrt(coef_Detera3)
coef_Correlacion3
# Out:
# 0.008293812407858474

# %%
#D) PRICE - calculated_host_listings_count

Indepa=dataframe[['calculated_host_listings_count']]
model1.fit(X=Indepa, y=Dep)

#Coeficiente de determinación D)
coef_Detera4 = model1.score(X=Indepa, y=Dep)
coef_Detera4
# Out:
# 0.0008119467599005947

# %%
#Correlación 4
coef_Correlacion4=np.sqrt(coef_Detera4)
coef_Correlacion4
# Out:
# 0.02849467950162968

# %%
#D) PRICE - availability_365

Indepa=dataframe[['availability_365']]
model1.fit(X=Indepa, y=Dep)

#Coeficiente de determinación D)
coef_Detera5 = model1.score(X=Indepa, y=Dep)
coef_Detera5
# Out:
# 0.0007399014313672625

# %%
#Correlación 5
coef_Correlacion5=np.sqrt(coef_Detera5)
coef_Correlacion5
# Out:
# 0.027201129229634247

# %%
#E) PRICE - number_of_reviews_ltm

Indepa=dataframe[['number_of_reviews_ltm']]
model1.fit(X=Indepa, y=Dep)

#Coeficiente de determinación E)
coef_Detera6 = model1.score(X=Indepa, y=Dep)
coef_Detera6
# Out:
# 4.4454976255714485e-08

# %%
#Correlación 6
coef_Correlacion6=np.sqrt(coef_Detera6)
coef_Correlacion6
# Out:
# 0.00021084348758193715

# %% [markdown]
# ##### MODELO DE PREDICCIÓN: "VARIABLE CON MAYOR CORRELACIÓN" #####

# %%
#Declaramos las variables dependientes e independientes para la regresión lineal
Vars_Indept= dataframe[['minimum_nights']]
Vars_Dept= dataframe['price']

# %%
#Se define model como la  de regresión lineal
from sklearn.linear_model import LinearRegression
import seaborn as sns
model1=LinearRegression()

# %%
type(model1)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
model1.fit(X=Vars_Indept, y=Vars_Dept)
# Out:
# LinearRegression()

# %%
model1.__dict__
# Out:
# {'fit_intercept': True,
#  'normalize': 'deprecated',
#  'copy_X': True,
#  'n_jobs': None,
#  'positive': False,
#  'feature_names_in_': array(['minimum_nights'], dtype=object),
#  'n_features_in_': 1,
#  'coef_': array([4.24760251]),
#  'rank_': 1,
#  'singular_': array([3932.53511422]),
#  'intercept_': 116.54718223007708}

# %% [markdown]
# $$
# total= 4.24760251 \cdot minimum_nights + 116.54718223007708
#
# $$

# %% [markdown]
# ****************************MODELO PREDICTIVO 1***************************

# %%
#Predecimos los valores del precio a partir de la variable "minimum_nights"
y_predict1= model1.predict(X=dataframe[['minimum_nights']])
y_predict1
# Out:
# array([120.79478474, 129.28998975, 133.53759226, ..., 120.79478474,
#        142.03279728, 120.79478474])

# %%
#Insertamos la columna de predicciones en el DataFrame
dataframe.insert(0, 'Predicciones', y_predict1)
dataframe
# Out:
#        Predicciones  Unnamed: 0                  id  \
# 0        120.794785           0  673276379194656210
# 1        129.289990           1            44192271
# 2        133.537592           2              196021
# 3        125.042387           3              196196
# 4        120.794785           4               18674
# ...             ...         ...                 ...
# 16915    120.794785       16915            26383234
# 16916    120.794785       16916            26383143
# 16917    120.794785       16917            26384664
# 16918    142.032797       16918            18220085
# 16919    120.794785       16919             5122846
#
#                                                     name    host_id  \
# 0                             HabitaciÃ³n muy acogedora.   51421682
# 1          Cozy terrace apartment\nApartamento con patio  200754964
# 2      Large patio, 4 baths (3 en-suite), 19th c, cen...     953719
# 3      â¨Large Apt near Sagrada Familia / Shared ter...     567180
# 4        Huge flat for 8 people close to Sagrada Familia      71615
# ...                                                  ...        ...
# 16915  LOVELY PRIVATE ROOM FOR 6 GUESTS ENSUITE BATHROOM  198281707
# 16916  LOVELY PRIVATE ROOM FOR 6 GUESTS ENSUITE BATHROOM  198281707
# 16917  HABITACION PRIVADA DE 6 CAMAS CON TERRAZA PRIVADA  198281707
# 16918  Chillout house,  with garden and pool  for family   10030977
# 16919  3 Peaceful, double bedrooms in musical family ...    1145453
#
#                                                host_name  \
# 0      <bound method Series.bfill of 0               ...
# 1      <bound method Series.bfill of 0               ...
# 2      <bound method Series.bfill of 0               ...
# 3      <bound method Series.bfill of 0               ...
# 4      <bound method Series.bfill of 0               ...
# ...                                                  ...
# 16915  <bound method Series.bfill of 0               ...
# 16916  <bound method Series.bfill of 0               ...
# 16917  <bound method Series.bfill of 0               ...
# 16918  <bound method Series.bfill of 0               ...
# 16919  <bound method Series.bfill of 0               ...
#
#                                neighbourhood   latitude  longitude  \
# 0                                 la Bordeta  41.363004   2.125326
# 1                 la Maternitat i Sant Ramon  41.372630   2.113180
# 2            l'Antiga Esquerra de l'Eixample  41.388420   2.161080
# 3                        la Sagrada FamÃ­lia  41.406600   2.174590
# 4                        la Sagrada FamÃ­lia  41.405560   2.172620
# ...                                      ...        ...        ...
# 16915             la Maternitat i Sant Ramon  41.373770   2.117570
# 16916             la Maternitat i Sant Ramon  41.373770   2.117570
# 16917             la Maternitat i Sant Ramon  41.374110   2.118520
# 16918                              Pedralbes  41.388440   2.087890
# 16919  Vallvidrera, el Tibidabo i les Planes  41.385100   2.076420
#
#              room_type  price  minimum_nights  number_of_reviews  \
# 0         Private room     59               1                  9
# 1      Entire home/apt    110               3                 54
# 2      Entire home/apt    386               4                316
# 3      Entire home/apt    245               2                103
# 4      Entire home/apt    180               1                 30
# ...                ...    ...             ...                ...
# 16915     Private room   5000               1                 30
# 16916     Private room   5000               1                  2
# 16917     Private room   5000               1                 13
# 16918  Entire home/apt    250               6                 12
# 16919     Private room     33               1                  5
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 0                   9.00                               1               351
# 1                   2.45                               1               151
# 2                   2.37                               1               238
# 3                   0.77                              19                22
# 4                   0.27                              38                60
# ...                  ...                             ...               ...
# 16915               0.59                              12                 0
# 16916               0.05                              12                 0
# 16917               0.33                              12                 0
# 16918               0.19                               1                 0
# 16919               0.06                               3                 0
#
#        number_of_reviews_ltm
# 0                          9
# 1                         40
# 2                         45
# 3                         11
# 4                          9
# ...                      ...
# 16915                      0
# 16916                      0
# 16917                      0
# 16918                      2
# 16919                      2
#
# [16920 rows x 17 columns]

# %%
#Visualizamos la gráfica comparativa entre el Precio real y el precio predecido

sns.scatterplot(x='minimum_nights', y='price', color="blue", data=dataframe)
sns.scatterplot(x='minimum_nights', y='Predicciones', color="red", data=dataframe)
# Out:
# <AxesSubplot:xlabel='minimum_nights', ylabel='price'>

# %%
#Corroboramos cual es el coeficiente de Determinación de nuestro modelo
coef_Deter1=model1.score(X=Vars_Indept, y=Vars_Dept)
coef_Deter1
# Out:
# 0.019168473426433796

# %%
#Corroboramos cual es el coeficiente de Correlación de nuestro modelo
coef_Correl1=np.sqrt(coef_Deter1)
coef_Correl1
# Out:
# 0.1384502561443416

# %%
#Graficamos todas las dispersiones entre las variables "Predicción, "price" y "minimum_nights"
sns.pairplot(dataframe[['price','minimum_nights']])
sns.pairplot(dataframe[['Predicciones','minimum_nights']])
